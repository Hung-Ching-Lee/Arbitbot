# %%
import sys
for mod in list(sys.modules.keys()):
    if 'arbitbot' in mod:
        del sys.modules[mod]

from arbitbot import ArbitrageDetector
detector = ArbitrageDetector()
detector.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 8
#       6 from arbitbot import ArbitrageDetector
#       7 detector = ArbitrageDetector()
# ----> 8 detector.show()
#
# AttributeError: 'ArbitrageDetector' object has no attribute 'show'
